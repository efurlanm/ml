# %% [markdown]
# # MNIST with TensorFlow using MPI through Horovod
#
# *Last edited: 2023-12-27*
#
# Based on: https://jean-zay-doc.readthedocs.io/en/latest/examples/tf/tf_mpi/
#
# This notebook runs on the [SDumont](https://sdumont.lncc.br/support_manual.php) computer on Sequana nodes, using V100 GPU. For more information, [see the Manual](https://sdumont.lncc.br/support_manual.php).

# %%
SCRA = ! SCRA=/scratch${HOME#/prj} && echo $SCRA
SCRA = SCRA[0]
# %env SCRA {SCRA}
SPWD = ! SPWD=/scratch${PWD#/prj} && echo $SPWD
SPWD = SPWD[0]
# %env SPWD {SPWD}
DATA = SCRA + '/data/MNIST/raw'
# %env DATA {DATA}
# Out:
# env: SCRA=/scratch/yyyy/xxxx
# env: SPWD=/scratch/yyyy/xxxx/horov-mnist
# env: DATA=/scratch/yyyy/xxxx/data/MNIST/raw

# %% [markdown]
# ---

# %%
# %%writefile {SPWD}/hv-tf1-mnist.py
import argparse
import errno
import gzip
import logging
import os
from os.path import join
import time
import numpy as np
import horovod.tensorflow as hvd
import tensorflow as tf
from tensorflow import keras

logging.disable(logging.WARNING)
logging.getLogger("tensorflow").disabled = True
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

DATA_PATH = join(os.environ["PWD"], "data~", "MNIST",
                 "raw").replace("/prj/", "/scratch/")

filename = [
    ["training_images",
     join(DATA_PATH, "train-images-idx3-ubyte.gz")],
    ["test_images", join(DATA_PATH, "t10k-images-idx3-ubyte.gz")],
    ["training_labels",
     join(DATA_PATH, "train-labels-idx1-ubyte.gz")],
    ["test_labels", join(DATA_PATH, "t10k-labels-idx1-ubyte.gz")],
]

layers = tf.layers

# Training settings
parser = argparse.ArgumentParser(description="Tensorflow MNIST Example")
parser.add_argument("--mnist", help="location of mnist.npz", required=True)
args = parser.parse_args()


def load_mnist():
    mnist = {}
    for name in filename[:2]:
        with gzip.open(name[1], "rb") as f:
            mnist[name[0]] = np.frombuffer(f.read(), np.uint8,
                                           offset=16).reshape(-1, 28 * 28)
    for name in filename[-2:]:
        with gzip.open(name[1], "rb") as f:
            mnist[name[0]] = np.frombuffer(f.read(), np.uint8, offset=8)
    return mnist


def conv_model(feature, target, mode):
    """2-layer convolution model."""

    # Convert the target to a one-hot tensor of shape (batch_size, 10)
    # and with a on-value of 1 for each one-hot vector of length 10
    target = tf.one_hot(tf.cast(target, tf.int32), 10, 1, 0)

    # Reshape feature to 4d tensor with 2nd and 3rd dimensions
    # being image width and height final dimension being the
    # number of color channels
    feature = tf.reshape(feature, [-1, 28, 28, 1])

    # First conv layer will compute 32 features for each 5x5 patch
    with tf.variable_scope("conv_layer1"):
        h_conv1 = layers.conv2d(feature,
                                32,
                                kernel_size=[5, 5],
                                activation=tf.nn.relu,
                                padding="SAME")
        h_pool1 = tf.nn.max_pool(h_conv1,
                                 ksize=[1, 2, 2, 1],
                                 strides=[1, 2, 2, 1],
                                 padding="SAME")

    # Second conv layer will compute 64 features for each 5x5 patch
    with tf.variable_scope("conv_layer2"):
        h_conv2 = layers.conv2d(h_pool1,
                                64,
                                kernel_size=[5, 5],
                                activation=tf.nn.relu,
                                padding="SAME")
        h_pool2 = tf.nn.max_pool(h_conv2,
                                 ksize=[1, 2, 2, 1],
                                 strides=[1, 2, 2, 1],
                                 padding="SAME")

        # reshape tensor into a batch of vectors
        h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])

    # Densely connected layer with 1024 neurons
    h_fc1 = layers.dropout(
        layers.dense(h_pool2_flat, 1024, activation=tf.nn.relu),
        rate=0.5,
        training=mode == tf.estimator.ModeKeys.TRAIN,
    )

    # Compute logits (1 per class) and compute loss
    logits = layers.dense(h_fc1, 10, activation=None)
    loss = tf.losses.softmax_cross_entropy(target, logits)

    return tf.argmax(logits, 1), loss


def train_input_generator(x_train, y_train, batch_size=64):
    assert len(x_train) == len(y_train)
    while True:
        p = np.random.permutation(len(x_train))
        x_train, y_train = x_train[p], y_train[p]
        index = 0
        while index <= len(x_train) - batch_size:
            yield x_train[index:index + batch_size], y_train[index:index +
                                                             batch_size],
            index += batch_size


def main(_):
    start = time.time()

    # Horovod: initialize Horovod
    hvd.init()

    # Load MNIST dataset
    dataset = load_mnist()
    x_train = dataset[filename[0][0]].reshape((60000, 28, 28))
    y_train = dataset[filename[2][0]].reshape((60000))
    x_test = dataset[filename[1][0]].reshape((10000, 28, 28))
    y_test = dataset[filename[3][0]].reshape((10000))

    # The shape of downloaded data is (-1, 28, 28), hence we need
    # to reshape it into (-1, 784) to feed into our network. Also,
    # need to normalize the features between 0 and 1
    x_train = np.reshape(x_train, (-1, 784)) / 255.0
    x_test = np.reshape(x_test, (-1, 784)) / 255.0

    # Build model...
    with tf.name_scope("input"):
        image = tf.placeholder(tf.float32, [None, 784], name="image")
        label = tf.placeholder(tf.float32, [None], name="label")
    predict, loss = conv_model(image, label, tf.estimator.ModeKeys.TRAIN)

    # Horovod: adjust learning rate based on lr_scaler
    lr_scaler = hvd.size()
    opt = tf.train.AdamOptimizer(0.001 * lr_scaler)

    # Horovod: add Horovod Distributed Optimizer
    opt = hvd.DistributedOptimizer(opt)

    global_step = tf.train.get_or_create_global_step()
    train_op = opt.minimize(loss, global_step=global_step)

    print("Mumber of GPUs:", hvd.size())
    hooks = [

        # Horovod: BroadcastGlobalVariablesHook broadcasts initial
        # variable states from rank 0 to all other processes. This is
        # necessary to ensure consistent initialization of all workers
        # when training is started with random weights or restored
        # from a checkpoint
        hvd.BroadcastGlobalVariablesHook(0),

        # Horovod: adjust number of steps based on number of GPUs.
        tf.train.StopAtStepHook(last_step=20000 // hvd.size()),
        tf.train.LoggingTensorHook(tensors={
            "step": global_step,
            "loss": loss
        },
                                   every_n_iter=10),
    ]

    # Horovod: pin GPU to be used to process local rank (one GPU per process)
    print("Hvd local rank(one GPU per process):", hvd.local_rank())
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.visible_device_list = str(hvd.local_rank())

    # Horovod: save checkpoints only on worker 0 to prevent other
    # workers from corrupting them
    print("Hdv rank:", hvd.rank())
    checkpoint_dir = "./checkpoints~" if hvd.rank() == 0 else None
    training_batch_generator = train_input_generator(x_train,
                                                     y_train,
                                                     batch_size=100)

    # The MonitoredTrainingSession takes care of session initialization,
    # restoring from a checkpoint, saving to a checkpoint, and closing
    # when done or an error occurs
    with tf.train.MonitoredTrainingSession(checkpoint_dir=checkpoint_dir,
                                           hooks=hooks,
                                           config=config) as mon_sess:
        while not mon_sess.should_stop():

            # Run a training step synchronously.
            image_, label_ = next(training_batch_generator)
            mon_sess.run(train_op, feed_dict={image: image_, label: label_})

    if hvd.rank() == 0:
        print("Elapsed time: ", time.time() - start)


if __name__ == "__main__":
    tf.app.run()
# Out:
# Overwriting /scratch/yyyy/xxxx/horov-mnist/hv-tf1-mnist.py

# %% [markdown]
# ---

# %% [markdown]
# Creates the working directory if it does not exist. The output file will be written to this directory:

# %%
! mkdir -p /scratch${PWD#/prj}

# %%
# %%writefile hv-tf1-mnist.srm
# #!/bin/bash
# #SBATCH -p sequana_gpu_shared       # SLURM_JOB_PARTITION
# #SBATCH --job-name=hv-tf1-mnist     # SLURM_JOB_NAME
# #SBATCH --nodes=1                   # SLURM_JOB_NUM_NODES
# #SBATCH --ntasks-per-node=1         # SLURM_NTASKS_PER_NODE
# #SBATCH --cpus-per-task=1           # SLURM_CPUS_PER_TASK
# #SBATCH --distribution=block:cyclic # SLURM_DISTRIBUTION
# #SBATCH --time=00:20:00             # Limit execution time
# # SLURM output environment variables:
# # https://slurm.schedmd.com/sbatch.html#SECTION_OUTPUT-ENVIRONMENT-VARIABLES
#
# echo '======================================='
# echo '- Job ID:' $SLURM_JOB_ID
# echo '- Nº of nodes in the job:' $SLURM_JOB_NUM_NODES
# echo '- Nº of tasks per node:' $SLURM_NTASKS_PER_NODE
# echo '- Nº of tasks:' $SLURM_NTASKS
# echo '- Nº of cpus per task:' $SLURM_CPUS_PER_TASK
# echo '- Partition:' $SLURM_JOB_PARTITION
# echo '- Dir from which sbatch was invoked:' ${SLURM_SUBMIT_DIR##*/}
# echo -n '- Nodes allocated to the job: '
# nodeset -e $SLURM_JOB_NODELIST
# echo '----------------------------------------'
#
# cd $SLURM_SUBMIT_DIR
#
# # Modules
# module purge
# module load sequana/current
# module load cuda/10.0_sequana cudnn/7.6_cuda-10.0_sequana
# module load openmpi/gnu/4.0.1_sequana
#
# # Environment
# DATA=data~/MNIST/raw
# SPWD=/scratch${PWD#/prj}
# SCRA=/scratch${HOME#/prj}
# source $SCRA/miniconda3/bin/activate
# conda activate tfh01 &>/dev/null
#
# # Executable
# PRMT="--mnist $SCRA/$DATA/mnist.npz"
# EXEC="python $SPWD/hv-tf1-mnist.py"
# OPTI="--mpi=pmi2 --cpu_bind=cores"
#
# # Run
# echo -n '<1. starting python script > ' && date
# echo '-- output -----------------------------'
# srun $OPTI $EXEC $PRMT
# echo '-- end --------------------------------'
# echo -n '<2. quit>                    ' && date
# Out:
# Overwriting hv-tf1-mnist.srm

# %%
def runtest(batch, nodes, tasks):
    import time
    sub = ! sbatch --nodes={nodes} --ntasks-per-node={tasks} {batch}
    print(sub[0], end='.')
    job = sub[0].replace('Submitted batch job ', '')
    c = [job]
    while job in c:
        time.sleep(20)
        print(end='.')
        c = ! squeue --job {job} --noheader --format "%i"
    print('')
    # %cat /scratch${{PWD#/prj}}/slurm-{job}.out

# %%
runtest('hv-tf1-mnist.srm', 1, 2)
# Out:
# Submitted batch job 11109057...............................
# =======================================
# - Job ID: 11109057
# - Nº of nodes in the job: 1
# - Nº of tasks per node: 2
# - Nº of tasks: 2
# - Nº of cpus per task: 1
# - Partition: sequana_gpu_shared
# - Dir from which sbatch was invoked: horov-mnist
# - Nodes allocated to the job: sdumont8038
# ----------------------------------------
# Loading SEQUANA Software environment
# <1. starting python script > Qua Dez 27 22:27:21 -03 2023
# -- output -----------------------------
# 2023-12-27 22:30:24.989571: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-27 22:30:24.989614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-27 22:30:33.917253: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-27 22:30:33.917253: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-27 22:30:37.553708: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-27 22:30:37.553707: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-27 22:30:37.642723: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559afaee4990 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-27 22:30:37.642740: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-27 22:30:37.642726: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x564a7d9dba70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-27 22:30:37.642741: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-27 22:30:38.020995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-27 22:30:38.020996: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-27 22:30:39.788730: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559afaf4d140 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-27 22:30:39.788758: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-27 22:30:39.789786: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x564a7da44150 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-27 22:30:39.789810: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-27 22:30:39.862117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:60:00.0
# 2023-12-27 22:30:39.862150: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:61:00.0
# 2023-12-27 22:30:39.862796: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-27 22:30:39.862799: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-27 22:30:52.314699: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-27 22:30:52.315615: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-27 22:30:55.761394: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-27 22:30:55.767627: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-27 22:30:57.526024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-27 22:30:57.526617: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-27 22:31:00.488280: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-27 22:31:00.488504: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-27 22:31:04.609322: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-27 22:31:04.614622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-27 22:31:13.712855: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-27 22:31:13.713162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-27 22:31:13.717036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2023-12-27 22:31:13.718875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 1
# 2023-12-27 22:31:13.981627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-27 22:31:13.981663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2023-12-27 22:31:13.981671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2023-12-27 22:31:13.991700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-27 22:31:13.991726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      1
# 2023-12-27 22:31:13.991734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   N
# 2023-12-27 22:31:14.196757: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:60:00.0, compute capability: 7.0)
# 2023-12-27 22:31:14.196840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:61:00.0, compute capability: 7.0)
# 2023-12-27 22:35:55.343400: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-27 22:35:55.353661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-27 22:35:56.870249: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-27 22:35:56.870249: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Mumber of GPUs: 2
# Hvd local rank(one GPU per process): 1
# Hdv rank: 1
# Mumber of GPUs: 2
# Hvd local rank(one GPU per process): 0
# Hdv rank: 0
# Elapsed time:  366.56352853775024
# -- end --------------------------------
# <2. quit>                    Qua Dez 27 22:36:41 -03 2023

# %%
! sacct -o JobID,JobName,AllocCPUS,Elapsed -j 11109057
# Out:
#        JobID    JobName  AllocCPUS    Elapsed
# ------------ ---------- ---------- ----------
# 11109057     hv-tf1-mn+          2   00:09:42
: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Mumber of GPUs: 4
# Hvd local rank(one GPU per process): 1
# Hdv rank: 1
# Mumber of GPUs: 4
# Hvd local rank(one GPU per process): 3
# Hdv rank: 3
# Mumber of GPUs: 4
# Hvd local rank(one GPU per process): 2
# Hdv rank: 2
# Mumber of GPUs: 4
# Hvd local rank(one GPU per process): 0
# Hdv rank: 0
# Elapsed time:  228.08413457870483
# -- end --------------------------------
# <2. quit>                    Qui Dez 28 12:26:20 -03 2023

# %%
! sacct -o JobID,AllocCPUS,Elapsed -j 11110682.0
# Out:
#        JobID  AllocCPUS    Elapsed
# ------------ ---------- ----------
# 11110682.0            4   00:07:36

# %%
runtest('hv-tf1-mnist.srm', 2, 4)
# Out:
# Submitted batch job 11111009.............................
# =======================================
# - Job ID: 11111009
# - Nº of nodes in the job: 2
# - Nº of tasks per node: 4
# - Nº of tasks: 8
# - Nº of cpus per task: 1
# - Partition: sequana_gpu_shared
# - Dir from which sbatch was invoked: horov-mnist
# - Nodes allocated to the job: sdumont8037 sdumont8038
# ----------------------------------------
# Loading SEQUANA Software environment
# <1. starting python script > Qui Dez 28 13:49:56 -03 2023
# -- output -----------------------------
# 2023-12-28 13:54:14.777233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.777233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.777233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.777233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.885490: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.885433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.885405: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:14.885467: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:43.826651: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:43.827641: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:43.829634: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:43.838632: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:44.171598: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:44.183759: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:44.201685: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 13:54:45.731714: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:45.732705: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:45.732705: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:45.743696: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:45.763802: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557d64cecdb0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:45.763818: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:45.764608: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5643f5781e70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:45.764621: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:45.767607: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55db39570e60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:45.767621: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:45.774610: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x564463431db0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:45.774625: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:45.957522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:45.958198: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:45.958197: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:45.959994: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:46.878749: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:46.886440: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:46.895418: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 13:54:46.927250: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5581b19ecb10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:46.927264: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:46.927446: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ec7b60c070 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:46.927461: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:46.928244: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5558e64dcb60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:46.928256: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 13:54:47.031212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:47.031209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:47.031211: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 13:54:48.730797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557d64d55430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:48.730824: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:48.730797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56446349a450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:48.730825: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:48.730797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55db395d9510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:48.730825: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:48.730797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5643f57ea510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:48.730825: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:48.867122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:61:00.0
# 2023-12-28 13:54:48.868308: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:48.986662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:89:00.0
# 2023-12-28 13:54:48.986718: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:48.992178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:60:00.0
# 2023-12-28 13:54:48.992235: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:49.002660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:88:00.0
# 2023-12-28 13:54:49.002703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:49.198577: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5581b1a551c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:49.198613: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:49.345707: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:61:00.0
# 2023-12-28 13:54:49.345756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:49.365575: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ec7b674720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:49.365597: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:49.368777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:88:00.0
# 2023-12-28 13:54:49.368816: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:49.369996: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5558e6545210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 13:54:49.370017: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-28 13:54:49.371309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:89:00.0
# 2023-12-28 13:54:49.371342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 13:54:58.580743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.553259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.553315: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.581617: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.581618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.563249: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:54:58.592613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 13:55:00.842385: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.847638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.847805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.847829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.850577: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.850577: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:00.853271: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-12-28 13:55:01.187294: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.187414: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.197395: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.474167: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.476650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.479643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:01.483621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-12-28 13:55:08.539627: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.539619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.512069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.540613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.513252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.540613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:08.513250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-12-28 13:55:09.549258: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-28 13:55:09.556850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-28 13:55:09.556826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-28 13:55:09.533242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-12-28 13:55
................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 runtest('hv-tf1-mnist.srm', 8, 4)
#
# Cell In[32], line 8, in runtest(batch, nodes, tasks)
#       6 c = [job]
#       7 while job in c:
# ----> 8     time.sleep(20)
#       9     print(end='.')
#      10     c = get_ipython().getoutput(' squeue --job {job} --noheader --format "%i"')
#
# KeyboardInterrupt:

# %%
! squeue -j 11111179 --start
# Out:
#              JOBID PARTITION     NAME     USER ST          START_TIME  NODES SCHEDNODES           NODELIST(REASON)
#           11111179 sequana_g hv-tf1-m eduardo. PD 2023-12-28T17:19:36      8 sdumont[8033,8036-80 (Resources)

# %%
! sacct -o JobID,AllocCPUS,Elapsed -j 11111179.0
# Out:
#        JobID  AllocCPUS    Elapsed
# ------------ ---------- ----------
# 11111179.0           32   00:05:24

# %%
! cat /scratch${PWD#/prj}/slurm-11111179.out
# Out:
# =======================================
# - Job ID: 11111179
# - Nº of nodes in the job: 8
# - Nº of tasks per node: 4
# - Nº of tasks: 32
# - Nº of cpus per task: 1
# - Partition: sequana_gpu_shared
# - Dir from which sbatch was invoked: horov-mnist
# - Nodes allocated to the job: sdumont8029 sdumont8030 sdumont8037 sdumont8038 sdumont8039 sdumont8040 sdumont8041 sdumont8042
# ----------------------------------------
# Loading SEQUANA Software environment
# <1. starting python script > Qui Dez 28 17:20:19 -03 2023
# -- output -----------------------------
# 2023-12-28 17:23:12.723306: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.739354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.723347: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.723342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.723342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.739357: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.739354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.739354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.785997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.782911: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.777218: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.782901: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.785997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.782877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784307: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.785997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.782932: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784930: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784300: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.786056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784811: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.777170: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.777169: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.784847: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:12.777210: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:21.699775: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.700764: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.700857: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.708754: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.709191: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.710078: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.710078: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:21.718068: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.045297: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.048036: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.048036: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.054029: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.387501: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.392652: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.393373: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.393838: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.408646: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.410633: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.411633: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.411634: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.431934: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.432921: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.435912: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.437972: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.502080: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.504302: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.504880: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.515623: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.550300: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.550299: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.552270: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:22.558271: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-12-28 17:23:23.867002: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.867984: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.867984: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.867983: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.912750: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.914724: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.914723: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.915738: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:23.990613: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5556669e7650 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.990630: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:23.991585: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55abd3ee2500 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.991583: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56189fbf92a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.991597: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:23.991598: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:23.995897: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fa9025b680 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.995915: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:24.002582: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x564f059ee760 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:24.002597: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:23.996891: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a9544710e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.996907: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:23.998892: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55852ae1bbf0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:23.998909: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:24.005889: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558390a65380 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:24.005905: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:24.167081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.167651: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.167652: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.175927: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.169966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.176547: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.177596: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.184165: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-28 17:23:24.204358: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.204447: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.205913: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.206139: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.206142: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.208122: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.206842: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.206842: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.205337: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.207357: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.208681: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.207357: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.206968: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.208680: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.207597: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.200015: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.207597: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.200015: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.207597: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.200016: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.200697: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.209864: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2023-12-28 17:23:24.209493: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ef9da05a10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:24.209508: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-28 17:23:24.210033: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e461fe0760 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:24.210033: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5643db7ec970 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-28 17:23:24
: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:35.025761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:89:00.0
# 2023-12-28 17:23:35.025801: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:35.030034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:88:00.0
# 2023-12-28 17:23:35.030074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-12-28 17:23:35.030243: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-SXM2-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:60:00.0
# 2023-12-28 17:23:35.030291: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...
# 2023-12-28 17:23:51.348589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:60:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.428495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-28 17:23:51.428532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      2
# 2023-12-28 17:23:51.428541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   N
# 2023-12-28 17:23:51.452155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0000:89:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.469420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-28 17:23:51.469452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      1
# 2023-12-28 17:23:51.469460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   N
# 2023-12-28 17:23:51.485271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-28 17:23:51.485297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2023-12-28 17:23:51.485305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2023-12-28 17:23:51.511223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-28 17:23:51.511249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      3
# 2023-12-28 17:23:51.511257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   N
# 2023-12-28 17:23:51.516349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:60:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.521557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:61:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.521519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0000:88:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.521640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0000:89:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.533679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0000:88:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.534746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:61:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.534873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:60:00.0, compute capability: 7.0)
# 2023-12-28 17:23:51.535443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30565 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0000:89:00.0, compute capability: 7.0)
# 2023-12-28 17:25:27.086845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.086878: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.079678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.087842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.087117: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.086810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.079678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.087835: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.087789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.080664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.088103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.088105: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.098082: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.098785: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.089662: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.098831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.097116: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.098082: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.098082: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.108162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.229805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.230683: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.228559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.228559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.230682: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.230607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.231559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.229474: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.232311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.238738: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.239062: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:27.238414: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-12-28 17:25:29.422111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.423098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.425802: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.425802: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.426785: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.427093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.433098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.436787: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.541626: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.551085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.543690: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.547972: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.552067: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.550857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.552065: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.543933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.551824: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.554056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.545656: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.546660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.934954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.929650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.935948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.930634: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.935948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.930636: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.939327: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.940619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.939756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.939750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.940800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-28 17:25:29.944943: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 1
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 21
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 2
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 22
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 23
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 20
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 3
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 13
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 29
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 15
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 31
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 18
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 14
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 30
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 12
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 28
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 19
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 16
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 4
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 5
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 7
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 6
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 17
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 9
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 10
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 8
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 11
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 3
# Hdv rank: 27
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 1
# Hdv rank: 25
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 2
# Hdv rank: 26
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 24
# Mumber of GPUs: 32
# Hvd local rank(one GPU per process): 0
# Hdv rank: 0
# Elapsed time:  150.0886173248291
# -- end --------------------------------
# <2. quit>                    Qui Dez 28 17:25:43 -03 2023

# %% [markdown]
# ---

# %%
! nvidia-smi
# Out:
# Sat Dec 23 16:39:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  Off  | 00000000:3B:00.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |    106MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-PCIE...  Off  | 00000000:5E:00.0 Off |                    0 |
# | N/A   30C    P0    25W / 250W |     15MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-PCIE...  Off  | 00000000:86:00.0 Off |                    0 |
# | N/A   30C    P0    24W / 250W |     15MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-PCIE...  Off  | 00000000:AF:00.0 Off |                    0 |
# | N/A   30C    P0    25W / 250W |     15MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     83088      G   /usr/bin/gnome-shell               65MiB |
# |    0   N/A  N/A    120961      G   /usr/bin/X                         39MiB |
# |    1   N/A  N/A    120961      G   /usr/bin/X                         14MiB |
# |    2   N/A  N/A    120961      G   /usr/bin/X                         14MiB |
# |    3   N/A  N/A    120961      G   /usr/bin/X                         14MiB |
# +-----------------------------------------------------------------------------+
