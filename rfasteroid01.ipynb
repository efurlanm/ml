# %% [markdown]
# # Random Forest Asteroid
#
# Based on *NASA: Asteroid Classification. Classifying whether an asteroid is hazardous or not* by Shubhankar Rawat, 2019
#
# https://towardsdatascience.com/nasa-asteroid-classification-6949bda3b1da
