# %% [markdown]
# # RF Iris
#
# Based on: https://www.datacamp.com/community/tutorials/random-forests-classifier-python

# %% [markdown]
# ![](http://raw.githubusercontent.com/efurlanm/ml/master/img/voting.png)

# %% [markdown]
# -
# ![](http://github.com/efurlanm/ml/blob/master/img/voting.png)
# -
